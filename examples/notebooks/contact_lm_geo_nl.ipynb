# %% [markdown]
# # Contact with the Lagrange Multiplier Method

# %%
import cmcrameri.cm as cmc
import equinox as eqx
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
from jax import Array

jax.config.update("jax_enable_x64", True)
jax.config.update("jax_persistent_cache_min_compile_time_secs", 0)
jax.config.update("jax_platforms", "cpu")

from femsolver.utils import auto_vmap, vmap
from femsolver import Mesh, Operator, element
from femsolver.compound import Compound, field

EPS = 1e-12

# %%
from typing import NamedTuple

from femsolver.operator import OperatorUpdatedLagrangian


class Material(NamedTuple):
    """Material properties for the elasticity operator."""

    mu: float  # Shear modulus
    lmbda: float  # First Lamé parameter


n = 30
mesh = Mesh.unit_square(n, n)
coords = mesh.coords
coords = coords.at[:, 0].add(0.05)
mesh = Mesh(coords, mesh.elements)

tri = element.Tri3()
op = Operator(mesh, tri)
material = Material(mu=1.0, lmbda=1.0)


n_nodes = mesh.coords.shape[0]
# contact nodes are those nodes on the left edge of the mesh
contact_nodes = jnp.where(jnp.isclose(mesh.coords[:, 0], 0.05))[0]
n_lambda = contact_nodes.size


class Solution(Compound):
    u = field(shape=(n_nodes, 2))
    lm = field(shape=(n_lambda,))


sol = Solution()
sol
# Out:
# Solution(u=(961, 2), lm=(31,))

# %%
plt.triplot(*mesh.coords.T, mesh.elements, color="k", lw=0.5)
plt.gca().set_aspect("equal")

# %% [markdown]
# ## Constitutive Model for Linear Elasticity
#
# We define a function to compute the linear elastic energy density based on the displacement gradients $\nabla u$.
#
# $$
# \Psi(x) =  \sigma(x) : \epsilon(x)
# $$
#
# where $\sigma$ is the stress tensor and $\epsilon$ is the strain tensor.
#
# $$
# \sigma = \lambda \text{tr}(\epsilon) I + 2\mu \epsilon
# $$
#
# and
#
# $$
# \epsilon = \frac{1}{2} (\nabla u + \nabla u^T)
# $$
#
# The elastic strain energy density is then given by:
#
# $$
# \Psi_{elastic}(u) = \int_{\Omega} \Psi(x) dV
# $$

# %% [markdown]
# The femsolver provides a generic class `Operator` that can be used to solve FEM problems. This operator is the core of the library as it provide functions that can automatically integrate the energy density function defined above over the range of elements.

# %%
@auto_vmap(grad_u=2)
def compute_strain(grad_u: Array) -> Array:
    """Compute the Green-Lagrange strain tensor from the displacement gradient."""
    F = jnp.eye(2) + grad_u  # Deformation gradient
    C = F.T @ F  # Right Cauchy-Green tensor
    return 0.5 * (C - jnp.eye(2))


@auto_vmap(grad_u=2)
def compute_stress(grad_u: Array, mat: Material) -> Array:
    """Compute the 2nd Piola-Kirchhoff stress tensor for a compressible Neo-Hookean material."""
    F = jnp.eye(2) + grad_u
    J = jnp.linalg.det(F)
    C = F.T @ F
    C_inv = jnp.linalg.inv(C)
    S = mat.mu * (jnp.eye(2) - C_inv) + mat.lmbda * jnp.log(J) * C_inv
    return S


@auto_vmap(grad_u=2)
def strain_energy(grad_u: Array, mat: Material) -> Array:
    """Neo-Hookean strain energy density (compressible)."""
    F = jnp.eye(2) + grad_u
    J = jnp.linalg.det(F)
    Ic = jnp.trace(F.T @ F)
    return (
        0.5 * mat.mu * (Ic - 2)
        - mat.mu * jnp.log(J)
        + 0.5 * mat.lmbda * (jnp.log(J)) ** 2
    )


def gap(x):
    # For a 45 degree slope, the gap is the signed distance to the line y = 0.5 + 5x -> y - 5x - 0.5 = 0
    return x[:, 1] - 3 * x[:, 0] - 0.5


def lagrangian(
    u: Array, lm: Array, contact_nodes: Array, mat: Material, op: Operator
) -> Array:
    # u = u_flat.reshape(-1, n_dofs_per_node)
    # strain_energy_density = strain_energy(op.grad(u), mat)
    strain_energy_density = strain_energy(op.grad(u), mat)
    g = gap((u + mesh.coords)[contact_nodes])
    contact_lm_term = jnp.sum(lm * g)

    return op.integrate(strain_energy_density) + contact_lm_term


dUdu = jax.grad(lagrangian, argnums=0)
dUdlm = jax.grad(lagrangian, argnums=1)


def jacobian(u: Array, op: Operator) -> Array:
    u, lm = Solution(u)
    return jnp.concatenate(
        [
            dUdu(u, lm, contact_nodes, material, op).flatten(),
            dUdlm(u, lm, contact_nodes, material, op),
        ]
    )


hessian = jax.jacfwd(jacobian)

# %% [markdown]
# ### Lagrange Multiplier Method for Contact
#
# The total potential energy $\Psi$ is the sum of the elastic strain energy $\Psi_{elastic}$ and the contact penalty energy $\Psi_{contact}$.
#
# Following a Lagrange multiplier approach, we define the total Lagrangian as:
#
# $$
# \mathcal{L}(u, \lambda) = \Psi_{elastic}(u) + \int_{\Gamma_c} \lambda g(u) dA
# $$
#
# Subject to the Kuhn-Tucker conditions
#
# $$
# g(u) \leq 0, \quad \lambda \geq 0, \quad \lambda g(u) = 0 \quad \text{on } \Gamma_c
# $$

# %% [markdown]
# ### Discrete Formulation
#
# Assign one multiplier per contact node (x dof for each node):
#
# $$
# \mathcal{L}(u, \lambda) = \Psi_{elastic}(u) + \sum_{i=1}^{N_c} \lambda_i g_i(u_i) A_i
# $$

# %%
def linear_solve(K: Array, rhs, active: Array, bc_dofs, bc_values) -> Array:
    jax.debug.print("Solving linear system with {n} dofs", n=K.shape[0])
    K = K.at[bc_dofs, :].set(0)
    K = K.at[:, bc_dofs].set(0)
    K = K.at[bc_dofs, bc_dofs].set(1.0)

    not_active = jnp.zeros(K.shape[0], dtype=bool)
    not_active = not_active.at[Solution.lm.slice.start :].set(~active)
    K = jnp.where(not_active[:, None], 0.0, K)
    K = jnp.where(not_active[None, :], 0.0, K)
    K = K.at[jnp.diag_indices_from(K)].set(jnp.where(not_active, 1.0, K.diagonal()))

    rhs = rhs.at[bc_dofs].set(bc_values)
    rhs = jnp.where(not_active, 0.0, rhs)

    return jnp.linalg.solve(K, rhs)


def solve_nr(
    sol: Solution,
    bc_dofs: Array,
    bc_values: Array,
    op: Operator,
    *,
    maxiter: int = 20,
    tol: float = 1e-6,
) -> Solution:
    u0 = sol.pack().at[bc_dofs].set(bc_values)
    res = jacobian(u0, op).at[bc_dofs].set(0.0)
    norm = jnp.linalg.norm(res)
    # active set of Lagrange multipliers
    active = jnp.zeros(Solution.lm.shape[0], dtype=bool)

    def cond_fn(carry: tuple) -> bool:
        *_, norm, contact_converged, i = carry
        jax.debug.print(
            "Residual norm: {norm} [it: {it}, cc: {cc}]",
            norm=norm,
            it=i,
            cc=contact_converged,
        )
        return ((norm > tol) | (~contact_converged)) & (i < maxiter)

    def body_fn(
        carry: tuple[Solution, Array, Operator, float, bool, int],
    ) -> tuple:
        sol, active, op, norm, contact_converged, i = carry

        delta = linear_solve(
            hessian(sol.arr, op),
            -jacobian(sol.arr, op),
            active,
            bc_dofs,
            bc_values - sol.arr[bc_dofs],
        )
        delta = Solution(delta)
        new = sol + delta

        # op = op.update_u(new.u)
        g = gap((mesh.coords + new.u)[contact_nodes])
        new.lm = jnp.maximum(new.lm, 0.0)
        new_active = (new.lm > EPS) | (g > EPS)
        contact_converged = jnp.all(active == new_active)

        res = jacobian(new.pack(), op).at[bc_dofs].set(0.0)
        res = Solution(res)
        res.lm = jnp.where(new_active, res.lm, 0.0)
        norm = jnp.linalg.norm(res.arr)

        return (new, new_active, op, norm, contact_converged, i + 1)

    sol, active, op, norm, contact_converged, i = jax.lax.while_loop(
        cond_fn, body_fn, (sol, active, op, norm, False, 0)
    )
    return sol

# %% [markdown]
# ## Solve system
#
# We arrange the system such that the unknown vector $u$ is flattened. Once we find the solution, we will reshape it back to the original shape.
#
# 1. create the unknown vector $u$ with the shape of the number of nodes times the number of degrees of freedom per node
# 2. create the system matrix $K$ and the right-hand side vector $f$
# 3. solve the system $K u = f$ for $u$
#
# ::: {.callout-note}
# We apply the boundary condition using matrix lifting
# :::

# %%
sol = Solution()

for i in jnp.linspace(0, -0.15, 10):
    right_nodes = jnp.where(jnp.isclose(mesh.coords[:, 0], 1.05))[0]
    bc_dofs = Solution.u.idx[right_nodes, :]

    # Apply Dirichlet BC: u_x on right_nodes (x-dof), free elsewhere
    bc_value_x = i * jnp.ones((right_nodes.size, 1))
    bc_value_y = jnp.zeros((right_nodes.size, 1))
    bc_values = jnp.hstack([bc_value_x, bc_value_y])

    sol = solve_nr(
        sol,
        bc_dofs,
        bc_values.flatten(),
        Operator(mesh, tri),
        maxiter=10,
        tol=1e-6,
    )

u = sol
# Out:
# Residual norm: 1.8582399079654799 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.7013875137500271 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.02801872486122503 [it: 2, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.009254324288026843 [it: 3, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.0024855787193839127 [it: 4, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 3.988470539699802e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 6.090307533906831e-09 [it: 6, cc: True]
# Residual norm: 1.7721231576330472 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.5735146457097418 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.2001482796253798 [it: 2, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.041598153704256714 [it: 3, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 0.002414584930414407 [it: 4, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 9.144526841241466e-06 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 1.496340942961818e-10 [it: 6, cc: True]
# Residual norm: 1.597481733698141 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.5869474658927567 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.2059230561976462 [it: 2, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.04346892166804657 [it: 3, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.0026323160793440318 [it: 4, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 1.1127784938316563e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 2.375050444703498e-10 [it: 6, cc: True]
# Residual norm: 1.4411553951191467 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.6024260285452625 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.21240702602070424 [it: 2, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 0.04581028505824655 [it: 3, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.0029027020177557527 [it: 4, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 1.3891819198883136e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 3.932655224871773e-10 [it: 6, cc: True]
# Residual norm: 1.304965541990467 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.6199929933968311 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.21995179509175608 [it: 2, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.04821556906893607 [it: 3, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 0.0032339176895301437 [it: 4, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 1.7596301512334738e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 6.566684208127163e-10 [it: 6, cc: True]
# Residual norm: 1.18966742124987 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.6396192589368627 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.22842860943503943 [it: 2, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.05109911411480434 [it: 3, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 0.003657334153905374 [it: 4, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 2.2555387958682222e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 1.1250928421571358e-09 [it: 6, cc: True]
# Residual norm: 1.097240281953793 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.6613624800125296 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.23773043186419873 [it: 2, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 0.054359626156284736 [it: 3, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.0040732449327381265 [it: 4, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 2.8802225896769853e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 1.8505973449972724e-09 [it: 6, cc: True]
# Residual norm: 1.0287401749209109 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.6852363128952306 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.24806759545823698 [it: 2, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 0.057985488440339336 [it: 3, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.0045904755130113896 [it: 4, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 3.6620028616956784e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 2.9876895415608514e-09 [it: 6, cc: True]
# Residual norm: 0.9816704497718458 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.7111483332116078 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.2593237429665021 [it: 2, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 0.06194222147974453 [it: 3, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.005176962037489186 [it: 4, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 4.607591694715694e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 4.6331950619817345e-09 [it: 6, cc: True]
# Residual norm: 0.9542537445292385 [it: 0, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.7391649688883485 [it: 1, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.2715477457605004 [it: 2, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 0.06627924937837501 [it: 3, cc: False]
# Solving linear system with 1953 dofs
# Residual norm: 0.005845736338412335 [it: 4, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 5.745543874836975e-05 [it: 5, cc: True]
# Solving linear system with 1953 dofs
# Residual norm: 6.870273018909108e-09 [it: 6, cc: True]

# %% [markdown]
# ## Postprocessing
#
# Let's plot the von Mises stress and the deformed configuration.

# %%
@auto_vmap(stress=2)
def von_mises_stress(stress):
    s_xx, s_yy = stress[0, 0], stress[1, 1]
    s_xy = stress[0, 1]
    return jnp.sqrt(s_xx**2 - s_xx * s_yy + s_yy**2 + 3 * s_xy**2)


# squeeze to remove the quad point dimension (only 1 quad point)
grad_u = op.grad(u.u).squeeze()
strains = compute_strain(grad_u)
stresses = compute_stress(strains, material)
stress_vm = von_mises_stress(stresses)

# %%
from matplotlib.pyplot import xlabel
from femsolver.plotting import STYLE_PATH
from matplotlib.axes import Axes

plt.style.use(STYLE_PATH)


def plot_displacement_and_stress(
    ax: Axes, u: Array, mesh: Mesh, stress: Array, scale=1.0
) -> None:
    coords, elements = mesh.coords, mesh.elements
    displaced = coords + scale * u

    ax.triplot(
        coords[:, 0],
        coords[:, 1],
        elements,
        color="black",
        linewidth=0.5,
    )
    cb = ax.tripcolor(
        displaced[:, 0],
        displaced[:, 1],
        elements,
        facecolors=stress,
        shading="flat",
        cmap=cmc.managua_r,
        edgecolors="black",
    )
    plt.colorbar(cb, label="Von Mises Stress")
    ax.set(xlabel="x", ylabel="y")
    ax.axis("equal")

    # Plot the gap=0 contour (the contact surface)
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    x = jnp.linspace(*xlim, 100)
    y = jnp.linspace(*ylim, 100)
    X, Y = jnp.meshgrid(x, y)
    pts = jnp.stack([X.ravel(), Y.ravel()], axis=-1)
    G = gap(pts).reshape(X.shape)
    ax.contour(X, Y, G, levels=[0], colors="red", linewidths=1, linestyles="--")


fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(111)

plot_displacement_and_stress(ax, u.u, mesh, stress_vm)

# %% [markdown]
# ### Rigid body rotation

# %%
def rigid_body_rotation_displacement_2d(
    X: Array, angle: float, center: Array = jnp.array([0.0, 0.0])
) -> Array:
    c = jnp.cos(angle)
    s = jnp.sin(angle)
    R = jnp.array([[c, -s], [s, c]])
    Xc = X - center
    rotated = (R @ Xc.T).T + center
    return rotated - X


u = rigid_body_rotation_displacement_2d(
    mesh.coords, jnp.pi / 4, center=jnp.array([0.5, 0.5])
)

op2 = Operator(mesh, tri)
strain_energy(op.grad(u), material)
# Out:
# Array([[ 2.22044605e-16],
#        [-2.22044605e-16],
#        [ 1.11022302e-16],
#        ...,
#        [ 7.79616441e-30],
#        [ 2.22044605e-16],
#        [ 4.12426342e-29]], dtype=float64)

# %%
@auto_vmap(stress=2)
def von_mises_stress(stress):
    s_xx, s_yy = stress[0, 0], stress[1, 1]
    s_xy = stress[0, 1]
    return jnp.sqrt(s_xx**2 - s_xx * s_yy + s_yy**2 + 3 * s_xy**2)


# squeeze to remove the quad point dimension (only 1 quad point)
grad_u = op.grad(u).squeeze()
strains = compute_strain(grad_u)
stresses = compute_stress(strains, material)
stress_vm = von_mises_stress(stresses)

# %%
from matplotlib.pyplot import xlabel
from femsolver.plotting import STYLE_PATH
from matplotlib.axes import Axes

plt.style.use(STYLE_PATH)


def plot_displacement_and_stress(
    ax: Axes, u: Array, mesh: Mesh, stress: Array, scale=1.0
) -> None:
    coords, elements = mesh.coords, mesh.elements
    displaced = coords + scale * u

    ax.triplot(
        coords[:, 0],
        coords[:, 1],
        elements,
        color="black",
        linewidth=0.5,
    )
    cb = ax.tripcolor(
        displaced[:, 0],
        displaced[:, 1],
        elements,
        facecolors=stress,
        shading="flat",
        cmap=cmc.managua_r,
        edgecolors="black",
    )
    plt.colorbar(cb, label="Von Mises Stress")
    ax.set(xlabel="x", ylabel="y")
    ax.axis("equal")

    # Plot the gap=0 contour (the contact surface)
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    x = jnp.linspace(*xlim, 100)
    y = jnp.linspace(*ylim, 100)
    X, Y = jnp.meshgrid(x, y)
    pts = jnp.stack([X.ravel(), Y.ravel()], axis=-1)
    G = gap(pts).reshape(X.shape)
    ax.contour(X, Y, G, levels=[0], colors="red", linewidths=1, linestyles="--")


fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(111)

plot_displacement_and_stress(ax, u, mesh, stress_vm)
